# %% [markdown]
# <a href="https://colab.research.google.com/github/ramdanginanjar/ramdanginanjar/blob/main/UasRamdanGinanjar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Membaca file CSV
data = pd.read_csv('/content/kebutuhan_per_bulan_2.csv')

# Menampilkan scatter plot
plt.figure(figsize=(12, 6))  # Mengatur ukuran figure
plt.scatter(data['Propinsi'], data['tahun'], s=50, c='blue', alpha=0.7)

# Menambahkan label pada setiap titik data
for i in range(len(data)):
    plt.annotate(data['kebutuhan'][i], (data['Propinsi'][i], data['tahun'][i]), ha='center', va='bottom', fontsize=8)

# Menambahkan judul dan label sumbu
plt.title('Kebutuhan Per Tahun Berdasarkan Provinsi', fontsize=14)
plt.xlabel('Propinsi', fontsize=12)
plt.ylabel('Tahun', fontsize=12)

# Mengatur rotasi dan ukuran font label sumbu X
plt.xticks(rotation=90, fontsize=8)

# Menambahkan grid
plt.grid(True, linestyle='--', alpha=0.5)

# Menampilkan scatter plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

d = pd.read_csv("/content/profile_pelanggan.csv")
d
x = d['15572']
y = d['DKI Jakarta']
plt.plot(x,y,'o')

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('kebutuhan_per_bulan_2.csv')

data_filtered_jabar = data[data['Propinsi'] == 'JAWA BARAT']

plt.scatter(data_filtered_jabar['tahun'], data_filtered_jabar['kebutuhan'], c=data_filtered_jabar.index, cmap='rainbow', s=50, alpha=0.7)

plt.title('Scatter Plot - Kebutuhan per Tahun (Jawa Barat)')
plt.xlabel('Tahun')
plt.ylabel('Kebutuhan')

cbar = plt.colorbar()
cbar.set_label('Data Index')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Membaca file CSV
data = pd.read_csv('/SupplyKantor.csv')

# Membuat scatter plot
plt.scatter(data['Jenis'], data['Jumlah'])

# Memberikan judul dan label sumbu
plt.title('Scatter Plot Distribusi Jumlah Pesanan')
plt.xlabel('Jenis')
plt.ylabel('Jumlah')

# Menampilkan scatter plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("/SupplyKantor.csv")

x = data['Jenis']
y = data['Kota']

plt.scatter(x,y)

plt.plot(x, y, color ='g', linestyle = 'dashed')

plt.xticks(rotation = 25)
plt.xlabel('Jenis')
plt.ylabel('Kota')
plt.title('Supply Kantor', fontsize = 12)
plt.grid()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("/transaksi2.csv")

plt.scatter(data['22704'], data['25'], c=data['15572'])

plt.title('Transaksi')
plt.xlabel('Number')
plt.ylabel('Jumlah')



plt.show()
